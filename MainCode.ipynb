# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iveeaten3223times/massive-yahoo-finance-dataset")

print("Path to dataset files:", path)
# Out:
# The kernel failed to start as the Python Environment 'Python 3.13.2' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
from google.cloud import bigquery
import pandas as pd
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./lustrous-router-454110-h9-0a05cb5bdaef.json"
#environment variables
print(os.environ["GOOGLE_APPLICATION_CREDENTIALS"])
# Out:
# ./lustrous-router-454110-h9-0a05cb5bdaef.json

# %%
client = bigquery.Client()
csv_file = csv_file = r"C:\Users\sande\.cache\kagglehub\datasets\iveeaten3223times\massive-yahoo-finance-dataset\versions\2\stock_details_5_years.csv"
df = pd.read_csv(csv_file)

# %%
# !pip install pandas-gbq
# Out:
# ...
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# Configure the job with matching schema
job_config = bigquery.LoadJobConfig(
    schema=[
        bigquery.SchemaField("High", "FLOAT"),
        bigquery.SchemaField("Volume", "INTEGER"),
        bigquery.SchemaField("Company", "STRING")
    ]
)

print(df.dtypes)

# Reference the correct dataset and table
table_ref = client.dataset("Sandeep01").table("stock_details")  # <-- **Ensure 'PythonProject' and 'User' exist in your BigQuery project**

# Load DataFrame to BigQuery
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()
print(job.output_rows)

# Correct the query format
query = "SELECT * FROM `lustrous-router-454110-h9.Sandeep01.stock_details`"  # <-- **Ensure dataset and table name are correct**

query_job = client.query(query)

# Fetch and print results
res = query_job.result()
for i in res:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Configure the job with matching schema
# ----> 2 job_config = bigquery.LoadJobConfig(
#       3     schema=[
#       4         bigquery.SchemaField("High", "FLOAT"),
#       5         bigquery.SchemaField("Volume", "INTEGER"),
#       6         bigquery.SchemaField("Company", "STRING")
#       7     ]
#       8 )
#      10 print(df.dtypes)
#      12 # Reference the correct dataset and table
#
# NameError: name 'bigquery' is not defined

# %%
pip install google-cloud-bigquery
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import bigquery

# %%
from google.cloud import bigquery
import pandas as pd
import os
from Cleaning import df 
# Ensure correct authentication
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./lustrous-router-454110-h9-0a05cb5bdaef.json"

client = bigquery.Client()




# Continue with BigQuery load
df['date'] = pd.to_datetime(df['date'], errors='coerce').dt.tz_convert(None)

job_config = bigquery.LoadJobConfig(
    schema=[
        bigquery.SchemaField("high", "FLOAT"),
        bigquery.SchemaField("volume", "INTEGER"),
        bigquery.SchemaField("company", "STRING"),
        bigquery.SchemaField("date", "TIMESTAMP")
    ],
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE

)

    


print(df.dtypes)

# Reference the correct dataset and table
table_ref = client.dataset("Sandeep01").table("stock_details")

# Load DataFrame to BigQuery
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()
print(job.output_rows)

# Run query
query = "SELECT * FROM `lustrous-router-454110-h9.Sandeep01.stock_details` limit 1000"
query_job = client.query(query)

# Print results
res = query_job.result()
for i in res:
    print(i)
# Out:
# date            datetime64[ns]
# open                   float64
# high                   float64
# low                    float64
# close                  float64
# volume                   int64
# dividends              float64
# stock_splits           float64
# company                 object
# dtype: object
# 473161
# Row((datetime.datetime(2018, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), 68.6734578320634, 69.5893580467354, 68.6734578320634, 69.0012512207031, 2625800, 0.0, 0.0, 'A'), {'date': 0, 'open': 1, 'high': 2, 'low': 3, 'close': 4, 'volume': 5, 'dividends': 6, 'stock_splits': 7, 'company': 8})
# Row((datetime.datetime(2018, 11, 30, 5, 0, tzinfo=datetime.timezone.utc), 69.0590757021374, 70.0424702989454, 68.7794834091454, 69.7532348632813, 2279500, 0.0, 0.0, 'A'), {'date': 0, 'open': 1, 'high': 2, 'low': 3, 'close': 4, 'volume': 5, 'dividends': 6, 'stock_splits': 7, 'company': 8})
# ...

# %%
print(df.columns)
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'dividends',
#        'stock_splits', 'company'],
#       dtype='object')
